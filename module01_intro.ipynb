# %%
# Q1. Pandas version
import pandas as pd
print(pd.__version__)
# Out:
# 2.1.2

# %%
# !wget https://raw.githubusercontent.com/alexeygrigorev/datasets/master/laptops.csv
# Out:
# --2024-09-17 09:01:00--  https://raw.githubusercontent.com/alexeygrigorev/datasets/master/laptops.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 298573 (292K) [text/plain]
# Saving to: ‘laptops.csv.1’
#
# laptops.csv.1       100%[===================>] 291.58K  1.26MB/s    in 0.2s
#
# 2024-09-17 09:01:01 (1.26 MB/s) - ‘laptops.csv.1’ saved [298573/298573]

# %%
df = pd.read_csv('laptops.csv')
df.head(20)
# Out:
#                                                Laptop Status   Brand  \
# 0   ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core...    New    Asus
# 1   Alurin Go Start Intel Celeron N4020/8GB/256GB ...    New  Alurin
# 2   ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core...    New    Asus
# 3   MSI Katana GF66 12UC-082XES Intel Core i7-1270...    New     MSI
# 4   HP 15S-FQ5085NS Intel Core i5-1235U/16GB/512GB...    New      HP
# 5   MSI Crosshair 17 C12VF-264XES Intel Core i7-12...    New     MSI
# 6   Lenovo Thinkpad E14 Gen 4 AMD Ryzen 5 5625U/8G...    New  Lenovo
# 7   ASUS VivoBook 15 F515JA-EJ2882W Intel Core i7-...    New    Asus
# 8   Medion Akoya E15415 Intel Core i5-10210U/8GB/2...    New  Medion
# 9   HP Victus 16-d1038ns Intel Core i7-12700H/16GB...    New      HP
# 10  Lenovo V15 IGL Intel Celeron N4020/8GB/256 GB ...    New  Lenovo
# 11  MSI Thin GF63 12VE-021XES Intel Core i7-12650H...    New     MSI
# 12  ASUS ROG Strix G15 G513RC-HN088 AMD Ryzen 7 68...    New    Asus
# ...

# %%
# Q2. Records count
len(df)
# Out:
# 2160

# %%
# Q3. Laptop brands 
unique_brands = df['Brand'].nunique()
brand_list = df['Brand'].unique()

print(f'Total unique brands: {unique_brands}')
print('Brands:', brand_list)
# Out:
# Total unique brands: 27
# Brands: ['Asus' 'Alurin' 'MSI' 'HP' 'Lenovo' 'Medion' 'Acer' 'Apple' 'Razer'
#  'Gigabyte' 'Dell' 'LG' 'Samsung' 'PcCom' 'Microsoft' 'Primux' 'Prixton'
#  'Dynabook Toshiba' 'Thomson' 'Denver' 'Deep Gaming' 'Vant' 'Innjoo'
#  'Jetwing' 'Millenium' 'Realme' 'Toshiba']

# %%
#Q4. Count missing values
missing_values = df.isnull().sum()
print(missing_values)
rows_with_missing = df[df.isnull().any(axis=1)]

print(rows_with_missing)
# Out:
# Laptop             0
# Status             0
# Brand              0
# Model              0
# CPU                0
# RAM                0
# Storage            0
# Storage type      42
# GPU             1371
# Screen             4
# Touch              0
# Final Price        0
# dtype: int64
#                                                  Laptop       Status  \
# 0     ASUS ExpertBook B1 B1502CBA-EJ0436X Intel Core...          New
# 1     Alurin Go Start Intel Celeron N4020/8GB/256GB ...          New
# 2     ASUS ExpertBook B1 B1502CBA-EJ0424X Intel Core...          New
# 4     HP 15S-FQ5085NS Intel Core i5-1235U/16GB/512GB...          New
# 6     Lenovo Thinkpad E14 Gen 4 AMD Ryzen 5 5625U/8G...          New
# ...                                                 ...          ...
# 2136  Microsoft Surface Pro 7 Intel Core i7-1065G7/1...  Refurbished
# 2137  Microsoft Surface Pro X Microsoft SQ1/8 GB/128...  Refurbished
# ...

# %%
#Q5. Maximum final price
dell_laptops = df[df['Brand']== 'Dell']
max_price = dell_laptops['Final Price'].max()
print(f'The maximum final price of Dell notebooks is: {max_price}')
# Out:
# The maximum final price of Dell notebooks is: 3936.0

# %%
#Q6. Median value of Screen
initial_median = df['Screen'].median()
print(f'median of Screen: {initial_median}')
# Out:
# median of Screen: 15.6

# %%
mode = df['Screen'].mode()[0]
print(f'Most frequent value of Screen column: {mode}')
# Out:
# Most frequent value of Screen column: 15.6

# %%
df['Screen'].fillna(most_frequent_value, inplace=True)

# %%
new_median = df['Screen'].median()
print(f'New median of Screen column: {new_median}')
# Out:
# New median of Screen column: 15.6

# %%
has_changed = initial_median != new_median
print(f'Has the median changed? {"Yes" if has_changed else "No"}')
# Out:
# Has the median changed? No

# %%
#Q7. Sum of weights
import numpy as np
innjoo_laptops = df[df['Brand'] == 'Innjoo']
X_df = innjoo_laptops[['RAM', 'Storage', 'Screen']]
X = X_df.to_numpy()
XTX = X.T @ X
XTX_inv = np.linalg.inv(XTX)
y = np.array([1100, 1300, 800, 900, 1000, 1100])
w = XTX_inv @ X.T @ y
sum_w = np.sum(w)
print(f'The sum of all elements in w: {sum_w}')
# Out:
# The sum of all elements in w: 91.2998806299557
